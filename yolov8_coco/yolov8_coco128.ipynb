# %%
# %pip install ultralytics  # install
from ultralytics import YOLO, checks, hub
checks()  # checks
# Out:
# Ultralytics YOLOv8.0.153 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %% [markdown]
# # Start
#
# Login with your [API key](https://hub.ultralytics.com/settings?tab=api+keys), select your YOLO 🚀 model and start training!

# %%
hub.login('2869cffe7cc647bc542e34c834a6510b024aa1c826')

model = YOLO('https://hub.ultralytics.com/models/McDcnELFOopqK3E4xPrJ')
model.train()
# Out:
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/McDcnELFOopqK3E4xPrJ 🚀
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 320MB/s]
# Ultralytics YOLOv8.0.153 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# define locale
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
# create a function that will return UTF-8 locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# # Inference on sample

# %%
# Now experinment our model on mp4 cars video
# !yolo task=detect mode=predict model=yolov8n.pt source='/content/drive/MyDrive/mixkit-two-avenues-with-many-cars-traveling-at-night-34562-medium (1).mp4' show=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.153 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# video 1/1 (1/198) /content/drive/MyDrive/mixkit-two-avenues-with-many-cars-traveling-at-night-34562-medium (1).mp4: 640x384 4 cars, 1 boat, 100.9ms
# video 1/1 (2/198) /content/drive/MyDrive/mixkit-two-avenues-with-many-cars-traveling-at-night-34562-medium (1).mp4: 640x384 5 cars, 6.4ms
# video 1/1 (3/198) /content/drive/MyDrive/mixkit-two-avenues-with-many-cars-traveling-at-night-34562-medium (1).mp4: 640x384 5 cars, 7.4ms
# video 1/1 (4/198) /content/drive/MyDrive/mixkit-two-avenues-with-many-cars-traveling-at-night-34562-medium (1).mp4: 640x384 5 cars, 1 boat, 6.8ms
# video 1/1 (5/198) /content/drive/MyDrive/mixkit-two-avenues-with-many-cars-traveling-at-night-34562-medium (1).mp4: 640x384 5 cars, 1 boat, 7.0ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
